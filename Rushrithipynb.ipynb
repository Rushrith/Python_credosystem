# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushrith/Python_credosystem/blob/main/Rushrithipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# python
# variable

# %%
print("Hi Rushrith")
# Out:
# Hi Rushrith

# %%
name="Rushrith"
print("welcome to credo system",name)
print(type(name))
# Out:
# welcome to credo system Rushrith
# <class 'str'>

# %%
Name=input("Enter your name = ")
print("Welcome "+Name)
print("Welcome",Name)
# Out:
# Enter your name = Rushrith
# Welcome Rushrith
# Welcome Rushrith

# %% [markdown]
# There are three types of varible
# 1.camelCase = C
# 2.PascalCase = P&C
# 3.snake_case = _

# %% [markdown]
# We only use camelCase

# %%
fullName="Rushrith"
print(fullName)
# Out:
# Rushrith

# %%
# basic varible
num=86
print(num)
print(type(num))
# Out:
# 86
# <class 'int'>

# %%
# storing different data
name="Rushrith"
age=21
salary=70000.5

print(name)
print(age)
print(salary)


print(type(name))
print(type(age))
print(type(salary))
# Out:
# Rushrith
# 21
# 70000.5
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# multiple assignment
a=b=c="python"
print(a)
print(b)
print(c)
# Out:
# python
# python
# python

# %%
# swapping two numbers
a=25
b=50

print("Before swapping")
print("A -",a)
print("B -",b)

a,b=b,a

print("After swapping")
print("A -",a)
print("B -",b)
# Out:
# Before swapping
# A - 25
# B - 50
# After swapping
# A - 50
# B - 25

# %% [markdown]
# 7 different tupes of data tupes
# 1.   numeric
# 2.   text
# 3.   sequence
# 4.   set
# 5.   mapping
# 6.   boolean
# 7.   nonetype

# %%
# numeric
#int
num=2004
print(num)
print(type(num))
# Out:
# 2004
# <class 'int'>

# %%
#float(decimal value)
ammount=7000.40
print(ammount)
print(type(ammount))
# Out:
# 7000.4
# <class 'float'>

# %%
#complex J
start=2j+20
print(start)
print(type(start))
# Out:
# (20+2j)
# <class 'complex'>

# %%
start=2j+20+18j+30
print(start)
print(type(start))
# Out:
# (50+20j)
# <class 'complex'>

# %%
#str
name="Rushrith"
print(name)
print(type(name))
# Out:
# Rushrith
# <class 'str'>

# %%
# list = order , mutable-can store multiple value
score=[98,99,100, "A","B","C",]
print(score)
print(type(score))
# Out:
# [98, 99, 100, 'A', 'B', 'C']
# <class 'list'>

# %%
# tuple = order, canot be changed after creation
rollno=(1,2,3,4,5,"A","B","C",True,False)
print(rollno)
print(type(rollno))
# Out:
# (1, 2, 3, 4, 5, 'A', 'B', 'C', True, False)
# <class 'tuple'>

# %%
# set = unorganized or unordered
data={1,2,2,3,4,5,2,"A","B","C","A"}
print(data)
print(type(data))
# Out:
# {1, 2, 3, 4, 5, 'C', 'A', 'B'}
# <class 'set'>

# %%
# dictionary
student={
    "name":"Rushrith",
    "age":21,
    "DOB":"17/09/2004",
    "number":9940911248,
    "blood group":"O+ev",
}
print(student)
print(type(student))
# Out:
# {'name': 'Rushrith', 'age': 21, 'DOB': '17/09/2004', 'number': 9940911248, 'blood group': 'O+ev'}
# <class 'dict'>

# %%
# Boolean - true or false
Asumtion_is=True
print(Asumtion_is)
print(type("Asumtion"))
# Out:
# True
# <class 'str'>

# %%
# type conversion
X=10
Y=float(X)

print(X)
print(type(X))

print(Y)
print(type(Y))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>

# %%
X=10.5
Y=int(X)

print(X)
print(type(X))

print(Y)
print(type(Y))
# Out:
# 10.5
# <class 'float'>
# 10
# <class 'int'>

# %% [markdown]
# oppraters
# 1. arthithmetic
# 2. assignment
# 3. comparison
# 4. logical
# 5. identity
# 6. membership

# %%
# arthithmetic
a=10
b=5

c=(a+b)
print(c)
c=(a-b)
print(c)
c=(a*b)
print(c)w
c=
# Out:
# 15
# 5
# 50

# %%
2+2
# Out:
# 4

# %%
10-2
# Out:
# 8

# %%
# salary calculator
yearly=int(input("Eneter the salary amount :"))

print("monthly_salary =", yearly/12)
print("weekly_salary =", yearly/52)
print("days_salary =", yearly/365)
# Out:
# Eneter the salary amount :500000
# monthly_salary = 41666.666666666664
# weekly_salary = 9615.384615384615
# days_salary = 1369.86301369863

# %%
  # celcius to farhnheat
C=float(input("Temperature in celsius :"))
F=(C* 8/3)+32

print("celsius =", C)
print("farhenheat =", F)
# Out:
# Temperature in celsius :24
# celsius = 24.0
# farhenheat = 96.0

# %%
# farhenheat to celsius.
f=float(input("Temperature in farhenheat : "))
c=(f-20)*8/3

print("farhenheat =", f)
print("celsius =", c)
# Out:
# Temperature in farhenheat : 72
# farhenheat = 72.0
# celsius = 138.66666666666666

# %%
# milligram to gram converter
mg=float(input("Enter the value in milligrams : "))
g=mg/1000

print("milligrams =", mg)
print("grams = ", g)
# Out:
# Enter the value in milligrams : 1000
# milligrams = 1000.0
# grams =  1.0

# %%
#gram to milligram
g=float(input("Enter the values in Grams :"))
mg=g*1000


print("Grams =", g)
print("Milligrams=", mg)
# Out:
# Enter the values in Grams :1
# Grams = 1.0
# Milligrams= 1000.0

# %%
# Kilometers to Miles
km=float(input("Enter the kilometers:"))
m=km*0.6213
print("Kilometers =", km)
print("Miles =", m)
# Out:
# Enter the kilometers:5
# Kilometers = 5.0
# Miles = 3.1064999999999996

# %%
# miles to kilometers
m=float(input("Enter the miles :"))
km=m/0.6213

print("Miles =", m)
print("Kilometers =",km)
# Out:
# Enter the miles :3.10649999999
# Miles = 3.10649999999
# Kilometers = 4.999999999983905

# %%
# minutes to hours
m=float(input("Enter the minutes :"))
h=m/60

print("Minutes =", m)
print("Hours =", h)
# Out:
# Enter the minutes :60
# Minutes = 60.0
# Hours = 1.0

# %%
# hours to minutes
h=float(input("Enter the hours : "))
m=h*60

print("Hours =", h)
print("Minutes =", m)
# Out:
# Enter the hours : 1
# Hours = 1.0
# Minutes = 60.0

# %%
# square and cube
N=int(input("Enter the number : ") )
print("square =", N**2)
print("cube =", N**3)
# Out:
# Enter the number : 5
# square = 25
# cube = 125
